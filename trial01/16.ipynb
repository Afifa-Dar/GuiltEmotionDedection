# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from scipy.io import loadmat
import seaborn as sns

# %%
data = loadmat('16openbci.mat')

# %%
data
# Out:
# {'__header__': b'MATLAB 5.0 MAT-file, Platform: PCWIN64, Created on: Tue Feb 14 11:13:03 2023',
#  '__version__': '1.0',
#  '__globals__': [],
#  'chdata': array([[ 1.85625977e+02,  2.04700562e+03,  1.69971216e+03, ...,
#           1.46353174e+03,  2.33785913e+03,  2.11139771e+03],
#         [-7.90538025e+01,  5.47318652e+03,  1.51795996e+03, ...,
#          -9.28129102e+03, -7.46618262e+03, -1.13169072e+04],
#         [ 7.10871267e+00, -5.26302588e+03,  1.87141699e+03, ...,
#           1.02718762e+03,  2.62584473e+03,  1.33475513e+03],
#         ...,
#         [-4.76329880e+01, -3.82145898e+03, -3.02021191e+03, ...,
#           3.62550928e+03,  2.53762891e+03,  4.61127637e+03],
#         [-7.94412384e+01,  1.92242114e+03, -5.24269189e+03, ...,
#           6.59010352e+03,  5.42772998e+03,  7.92417480e+03],
#         [ 4.00075302e+01,  7.64044189e+02,  4.64124219e+03, ...,
#          -9.17436426e+03, -7.91361816e+03, -1.07564736e+04]]),
# ...

# %%
data = pd.DataFrame(data['chdata'])

# %%
data.head()
# Out:
#            0            1            2            3            4   \
# 0  185.625977  2047.005615  1699.712158  1254.635498    -9.170894
# 1  -79.053802  5473.186523  1517.959961  2414.217041  1474.996460
# 2    7.108713 -5263.025879  1871.416992  2359.190186  2558.845703
# 3   53.796299  7031.471191 -7569.791504 -6946.363770 -5690.726074
# 4  -87.142258  -272.540039  1906.975098   691.908020  2706.274902
#
#             5            6            7             8            9   \
# 0 -2110.541016  -166.835297 -2453.850342   2738.549805  2216.750244
# 1 -1933.680176  2334.455322  1101.402466 -10925.656250 -8607.339844
# 2  7306.112305  3355.395264  5068.320312   1375.713135   346.342316
# 3 -9181.671875 -7243.321777 -5731.108398   3111.625488  2436.031494
# 4  3511.648438  3119.327393  3974.390869   2672.809082  3003.962158
#
#             10            11           12           13           14  \
# 0  3365.007080   3066.762207  2762.525391  1463.531738  2337.859131
# ...

# %%
data.shape
# Out:
# (15031, 16)

# %%
len(data)
# Out:
# 15031

# %%
time = [i/125 for i in range(0,len(data))]

# %%
plt.plot(time,np.array(data))

# %%
channel = [i for i in range(0,16)]

# %%
plt.figure(figsize=(30,30))
for i , col in enumerate(channel,1):
    plt.subplot(4,4,i)
    plt.plot(time , data[col])

# %%
data.nunique()
# Out:
# 0     1251
# 1     1251
# 2     1251
# 3     1251
# 4     1251
# 5     1251
# 6     1251
# 7     1251
# 8     1251
# 9     1251
# 10    1251
# 11    1251
# 12    1251
# 13    1251
# 14    1251
# 15    1251
# dtype: int64

# %%
data.describe()
# Out:
#                  0             1             2             3             4   \
# count  15031.000000  15031.000000  15031.000000  15031.000000  15031.000000
# mean       0.821395    -82.961628     17.541284     -7.012651     17.870245
# std       74.284687   2541.871004   4203.936909   4239.576395   3660.657786
# min     -327.100220 -18175.259766  -9058.211914 -10273.835938 -12943.959961
# 25%      -60.360382  -1535.079468  -3124.634277  -3441.319092  -1985.616089
# 50%       -8.094430    135.047073    326.138519    105.396660    408.244690
# 75%       44.249550   1332.576294   3997.594238   3968.751709   3266.231689
# max      406.829285  11824.608398   7546.406738   6774.335938   8334.379883
#
#                  5             6             7             8             9   \
# count  15031.000000  15031.000000  15031.000000  15031.000000  15031.000000
# mean      15.241560     19.107261     18.734680     -2.236260      9.610920
# ...

# %% [markdown]
# # eye close

# %%
eye_close = data.iloc[:len(data)//2]

# %%
eye_close.head()
# Out:
#            0            1            2            3            4   \
# 0  185.625977  2047.005615  1699.712158  1254.635498    -9.170894
# 1  -79.053802  5473.186523  1517.959961  2414.217041  1474.996460
# 2    7.108713 -5263.025879  1871.416992  2359.190186  2558.845703
# 3   53.796299  7031.471191 -7569.791504 -6946.363770 -5690.726074
# 4  -87.142258  -272.540039  1906.975098   691.908020  2706.274902
#
#             5            6            7             8            9   \
# 0 -2110.541016  -166.835297 -2453.850342   2738.549805  2216.750244
# 1 -1933.680176  2334.455322  1101.402466 -10925.656250 -8607.339844
# 2  7306.112305  3355.395264  5068.320312   1375.713135   346.342316
# 3 -9181.671875 -7243.321777 -5731.108398   3111.625488  2436.031494
# 4  3511.648438  3119.327393  3974.390869   2672.809082  3003.962158
#
#             10            11           12           13           14  \
# 0  3365.007080   3066.762207  2762.525391  1463.531738  2337.859131
# ...

# %%
eye_close_time = time[:len(time)//2]

# %%
plt.plot(np.array(eye_close_time),np.array(eyeOpen))

# %%
eye_close.describe()
# Out:
#                 0             1            2             3             4   \
# count  7515.000000   7515.000000  7515.000000   7515.000000   7515.000000
# mean      0.844177   -129.938317    29.146538    -20.956268     18.044728
# std      79.358158   2893.449597  4167.602910   4163.413249   3684.685346
# min    -327.100220 -18175.259766 -9058.211914 -10273.835938 -12943.959961
# 25%     -60.163841  -1647.499268 -3039.269775  -3314.600586  -1982.640381
# 50%      -9.177142    130.137390   396.611115    132.186447    421.287506
# 75%      46.347466   1473.597900  3929.778076   3807.413574   3246.533447
# max     406.829285  11824.608398  7546.406738   6774.335938   8334.379883
#
#                  5             6             7             8             9   \
# count   7515.000000   7515.000000   7515.000000   7515.000000   7515.000000
# mean       9.860824     19.946844     23.753773     -6.372823     15.581605
# ...

# %% [markdown]
# # eye open

# %%
eye_open = data.iloc[len(data)//2:]

# %%
eye_open.head()
# Out:
#               0            1            2            3            4   \
# 7515  125.465393  -619.978943  4333.888184  4416.215820  4500.487793
# 7516   -6.351629  -589.761841 -3841.614502 -3469.633057 -1830.006714
# 7517  -56.105995 -3203.591553 -3498.028564 -4020.279053 -1655.677856
# 7518  -13.732623  3377.745117 -1783.829102 -2095.948486 -3385.792969
# 7519   35.993488  1047.465088  5327.913086  5602.637207  3744.280762
#
#                5            6            7            8            9   \
# 7515  3225.590088  6209.427734  3246.007324 -5095.707520 -3988.240479
# 7516 -2649.372559 -2063.995850 -1582.712036 -3864.755371 -3780.472656
# 7517    34.507854 -3021.980469  -864.970459  6990.164062  5398.846680
# 7518 -3381.205322 -4849.772461 -3262.458008  6128.515137  5362.723633
# 7519  3536.889893  5317.373047  2836.129150 -5204.598633 -3863.174805
#
#                10           11           12           13           14  \
# ...

# %%
eye_open_time = time[len(time)//2:]

# %%
plt.plot(np.array(eye_open_time),np.array(eye_open))

# %%
eye_open.describe()
# Out:
#                 0            1            2            3            4   \
# count  7516.000000  7516.000000  7516.000000  7516.000000  7516.000000
# mean      0.798615   -35.991190     5.937575     6.929111    17.695784
# std      68.844384  2132.338282  4240.200342  4314.617469  3636.719859
# min    -116.844612 -5069.858887 -8479.673828 -8342.780273 -7516.988281
# 25%     -60.546005 -1310.870850 -3189.232910 -3517.598145 -1990.598389
# 50%      -7.995922   136.349121   258.992645    66.236130   378.639465
# 75%      38.744431  1221.963867  4149.818359  4113.027344  3347.544434
# max     170.582779  4250.115723  6106.097168  6082.099609  4995.317871
#
#                 5            6            7             8            9   \
# count  7516.000000  7516.000000  7516.000000   7516.000000  7516.000000
# mean     20.621579    18.267789    13.716254      1.899753     3.641030
# std    3141.248928  4849.596157  2939.423623   5850.706526  4793.372396
# ...

# %%
# fL = 3
# fH = 40
# b = 0.08
# N = int(np.ceil((4 / b)))
# if not N % 2: N += 1  # Make sure that N is odd.
# n = np.arange(N)

# # low-pass filter
# hlpf = np.sinc(2 * fH * (n - (N - 1) / 2.))
# hlpf *= np.blackman(N)
# hlpf = hlpf / np.sum(hlpf)

# # high-pass filter 
# hhpf = np.sinc(2 * fL * (n - (N - 1) / 2.))
# hhpf *= np.blackman(N)
# hhpf = hhpf / np.sum(hhpf)
# hhpf = -hhpf
# hhpf[int((N - 1) / 2)] += 1

# h = np.convolve(hlpf, hhpf)
# s = list(data)
# new_signal = np.convolve(s, h)

# trace1 = go.Scatter(
#     x=list(range(len(new_signal))),
#     y=new_signal,
#     mode='lines',
#     name='Band-Pass Filter',
#     marker=dict(
#         color='#BB47BE'
#     )
# )

# layout = go.Layout(
#     title='Band-Pass Filter',
#     showlegend=True
# )

# trace_data = [trace1]
# fig = go.Figure(data=trace_data, layout=layout)
# py.iplot(fig, filename='fft-band-pass-filter')
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-35-f296b9be2a62> in <module>
#      22 new_signal = np.convolve(s, h)
#      23
# ---> 24 trace1 = go.Scatter(
#      25     x=list(range(len(new_signal))),
#      26     y=new_signal,
#
# NameError: name 'go' is not defined
