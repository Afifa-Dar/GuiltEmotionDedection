# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from scipy.io import loadmat

# %%
control = loadmat('control.mat')

# %%
control
# Out:
# {'__header__': b'MATLAB 5.0 MAT-file, Platform: PCWIN64, Created on: Wed Jan 18 10:05:01 2023',
#  '__version__': '1.0',
#  '__globals__': [],
#  'CN': array([[-606525.3125  ,  413270.53125 ,  179221.46875 , ...,
#          -190770.      ,   91851.71875 ,  221700.15625 ],
#         [-607258.125   ,  411046.4375  ,  178949.5     , ...,
#          -190746.921875,   92095.265625,  221353.078125],
#         [-606561.8125  ,  412474.4375  ,  179191.4375  , ...,
#          -190868.703125,   92056.640625,  221120.796875],
#         ...,
#         [-389730.375   ,  475828.21875 ,  271691.1875  , ...,
#          -194725.71875 ,   96291.3125  ,  317945.875   ],
#         [-389554.4375  ,  477244.96875 ,  272107.46875 , ...,
#          -194810.46875 ,   95753.796875,  319726.3125  ],
#         [-389818.90625 ,  475629.21875 ,  271631.09375 , ...,
#          -194767.5625  ,   96007.      ,  319032.15625 ]])}

# %%
len(control['CN'])
# Out:
# 15627

# %%
guilt = loadmat('Guilt.mat')

# %%
guilt
# Out:
# {'__header__': b'MATLAB 5.0 MAT-file, Platform: PCWIN64, Created on: Wed Jan 18 10:19:58 2023',
#  '__version__': '1.0',
#  '__globals__': [],
#  'CG': array([[-457277.       ,  459008.09375  ,  199905.59375  , ...,
#          -187177.4375   ,  103806.328125 ,  278456.78125  ],
#         [-457704.53125  ,  457118.75     ,  199507.015625 , ...,
#          -187146.859375 ,  103952.2421875,  278223.4375   ],
#         [-457366.59375  ,  457964.1875   ,  199718.375    , ...,
#          -187107.703125 ,  103903.9609375,  277770.65625  ],
#         ...,
#         [-397042.625    ,  472727.0625   ,  252359.953125 , ...,
#          -193418.9375   ,   94268.9296875,  317171.25     ],
#         [-397026.53125  ,  471919.1875   ,  252094.953125 , ...,
#          -193250.5      ,   94837.5546875,  315019.59375  ],
#         [-396811.40625  ,  473628.8125   ,  252457.046875 , ...,
#          -193058.984375 ,   94433.6171875,  316859.59375  ]])}

# %%
len(guilt['CG'])
# Out:
# 10418

# %%
ts = 125

# %%
lenguilt = len(guilt['CG'])
guiltT = [i/ts for i in range(0,lenguilt)]

# %%
print(guiltT)
# Out:
# [0.0, 0.008, 0.016, 0.024, 0.032, 0.04, 0.048, 0.056, 0.064, 0.072, 0.08, 0.088, 0.096, 0.104, 0.112, 0.12, 0.128, 0.136, 0.144, 0.152, 0.16, 0.168, 0.176, 0.184, 0.192, 0.2, 0.208, 0.216, 0.224, 0.232, 0.24, 0.248, 0.256, 0.264, 0.272, 0.28, 0.288, 0.296, 0.304, 0.312, 0.32, 0.328, 0.336, 0.344, 0.352, 0.36, 0.368, 0.376, 0.384, 0.392, 0.4, 0.408, 0.416, 0.424, 0.432, 0.44, 0.448, 0.456, 0.464, 0.472, 0.48, 0.488, 0.496, 0.504, 0.512, 0.52, 0.528, 0.536, 0.544, 0.552, 0.56, 0.568, 0.576, 0.584, 0.592, 0.6, 0.608, 0.616, 0.624, 0.632, 0.64, 0.648, 0.656, 0.664, 0.672, 0.68, 0.688, 0.696, 0.704, 0.712, 0.72, 0.728, 0.736, 0.744, 0.752, 0.76, 0.768, 0.776, 0.784, 0.792, 0.8, 0.808, 0.816, 0.824, 0.832, 0.84, 0.848, 0.856, 0.864, 0.872, 0.88, 0.888, 0.896, 0.904, 0.912, 0.92, 0.928, 0.936, 0.944, 0.952, 0.96, 0.968, 0.976, 0.984, 0.992, 1.0, 1.008, 1.016, 1.024, 1.032, 1.04, 1.048, 1.056, 1.064, 1.072, 1.08, 1.088, 1.096, 1.104, 1.112, 1.12, 1.128, 1.136, 1.144, 1.152, 1.16, 1.168, 1.17
# ...

# %%
lencontrol = len(control['CN'])
controlT = [i/ts for i in range(0,lencontrol)]

# %%
plt.figure(figsize=(10,10))
# plt.subplot(1,2,1)
plt.plot(guiltT,guilt['CG'])

# %%
plt.figure(figsize=(10,10))

plt.plot(controlT,control['CN'])

# %%
# ax1 = plt.subplot(1,3,1)
# plt.plot(guiltT,guilt['CG'], ax = ax1)

# ax2 = plt.subplot(1,3,2)
# plt.plot(controlT,control['CN'] , ax = ax2)

# ax3 = plt.subplot(1,3,3)
# plt.plot(controlT,std['CN'] , ax = ax3)

# %%
print("guilt channel data length", len(guilt['CG']))
print("control channel data length", len(control['CN']))
# Out:
# guilt channel data length 10418
# control channel data length 15627

# %%
dic = {}
for i in range (16):
    dic[i] = f"ch_{i+1}"
print(dic)
# Out:
# {0: 'ch_1', 1: 'ch_2', 2: 'ch_3', 3: 'ch_4', 4: 'ch_5', 5: 'ch_6', 6: 'ch_7', 7: 'ch_8', 8: 'ch_9', 9: 'ch_10', 10: 'ch_11', 11: 'ch_12', 12: 'ch_13', 13: 'ch_14', 14: 'ch_15', 15: 'ch_16'}

# %%
guiltData = pd.DataFrame(guilt['CG'])

# %%
guiltData['Label'] = "Guilt"

# %%
guiltData.rename(columns=dic , inplace=True)

# %%
guiltData
# Out:
#                ch_1          ch_2           ch_3           ch_4          ch_5  \
# 0     -457277.00000  459008.09375  199905.593750 -246188.734375  17225.037109
# 1     -457704.53125  457118.75000  199507.015625 -245910.859375  17148.615234
# 2     -457366.59375  457964.18750  199718.375000 -246231.109375  17166.095703
# 3     -457015.75000  458894.37500  199792.953125 -246017.062500  17220.185547
# 4     -457274.31250  457177.21875  199443.187500 -245839.500000  17118.417969
# ...             ...           ...            ...            ...           ...
# 10413 -397284.03125  471720.68750  252115.875000 -239525.578125  16217.754883
# 10414 -396885.96875  472913.75000  252473.687500 -239808.296875  16255.015625
# 10415 -397042.62500  472727.06250  252359.953125 -239547.578125  16275.780273
# 10416 -397026.53125  471919.18750  252094.953125 -239554.546875  16205.841797
# 10417 -396811.40625  473628.81250  252457.046875 -239707.968750  16300.903320
#
# ...

# %%
plt.figure(figsize=(10,10))
# plt.subplot(1,2,1)
plt.plot(guiltT,guiltData['ch_1'])

# %%
controlData = pd.DataFrame(control['CN'])

# %%
controlData["Label"] = 'Control'

# %%
controlData.rename(columns = dic , inplace = True)

# %%
controlData
# Out:
#                ch_1          ch_2           ch_3           ch_4          ch_5  \
# 0     -606525.31250  413270.53125  179221.468750 -249587.093750  19927.474609
# 1     -607258.12500  411046.43750  178949.500000 -249343.000000  19850.562500
# 2     -606561.81250  412474.43750  179191.437500 -249621.953125  19885.789062
# 3     -606992.00000  412223.93750  179174.265625 -249529.687500  19905.792969
# 4     -607166.87500  410844.18750  178936.078125 -249622.500000  19826.847656
# ...             ...           ...            ...            ...           ...
# 15622 -389656.34375  476813.12500  271870.343750 -240021.250000  16134.316406
# 15623 -389789.93750  476503.06250  271791.500000 -239771.812500  16156.421875
# 15624 -389730.37500  475828.21875  271691.187500 -239800.781250  16095.983398
# 15625 -389554.43750  477244.96875  272107.468750 -239987.468750  16187.536133
# 15626 -389818.90625  475629.21875  271631.093750 -239667.750000  16106.711914
#
# ...

# %%
channels = [f'ch_{i}' for i in range(1,17)]
channels
# Out:
# ['ch_1',
#  'ch_2',
#  'ch_3',
#  'ch_4',
#  'ch_5',
#  'ch_6',
#  'ch_7',
#  'ch_8',
#  'ch_9',
#  'ch_10',
#  'ch_11',
#  'ch_12',
#  'ch_13',
#  'ch_14',
#  'ch_15',
#  'ch_16']

# %%
plt.figure(figsize=(30,30))
for i , col in enumerate(channels,1):
    plt.subplot(4,4,i)
    plt.plot(guiltT, guiltData[col])

# %%
plt.figure(figsize=(30,30))
for i , col in enumerate(channels,1):
    plt.subplot(4,4,i)
    plt.plot(controlT,controlData[col])

# %%
data = [guiltData  , controlData]    #neglect student bcz its actually a control file

# %%
all_data = pd.concat(data)

# %%
all_data
# Out:
#                ch_1          ch_2           ch_3           ch_4          ch_5  \
# 0     -457277.00000  459008.09375  199905.593750 -246188.734375  17225.037109
# 1     -457704.53125  457118.75000  199507.015625 -245910.859375  17148.615234
# 2     -457366.59375  457964.18750  199718.375000 -246231.109375  17166.095703
# 3     -457015.75000  458894.37500  199792.953125 -246017.062500  17220.185547
# 4     -457274.31250  457177.21875  199443.187500 -245839.500000  17118.417969
# ...             ...           ...            ...            ...           ...
# 15622 -389656.34375  476813.12500  271870.343750 -240021.250000  16134.316406
# 15623 -389789.93750  476503.06250  271791.500000 -239771.812500  16156.421875
# 15624 -389730.37500  475828.21875  271691.187500 -239800.781250  16095.983398
# 15625 -389554.43750  477244.96875  272107.468750 -239987.468750  16187.536133
# 15626 -389818.90625  475629.21875  271631.093750 -239667.750000  16106.711914
#
# ...

# %%
all_data.to_csv('student_data.csv')
